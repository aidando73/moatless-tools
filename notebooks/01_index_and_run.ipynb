# %% [markdown]
# # Run Moatless Tools

# %% [markdown]
# First, index the codebase in a vector store.
#
# Set `repo_dir` to the path of the repository you want to index.

# %%
from moatless.index import CodeIndex, IndexSettings
from moatless.repository import FileRepository
from moatless.workspace import Workspace
import logging
logging.basicConfig(level=logging.INFO)

# An OPENAI_API_KEY is required to use the OpenAI Models
model = "gpt-4o-2024-05-13"
index_settings = IndexSettings(
    embed_model="text-embedding-3-small"
)

repo_dir = "/Users/aidand/dev/hello-swe-bench/django"
file_repo = FileRepository(repo_path=repo_dir)

code_index = CodeIndex(file_repo=file_repo, settings=index_settings)
nodes, tokens = code_index.run_ingestion()

print(f"Indexed {nodes} nodes and {tokens} tokens")

# workspace = Workspace(file_repo=file_repo, code_index=code_index)
# Out:
# INFO:moatless.index.code_index:Read 2750 documents
# Parsing nodes:   0%|          | 0/2750 [00:00<?, ?it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/__main__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/apps/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/apps/config.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   0%|          | 4/2750 [00:00<01:20, 34.03it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/apps/registry.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/global_settings.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   0%|          | 8/2750 [00:00<01:21, 33.57it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ar/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ar_DZ/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   0%|          | 12/2750 [00:00<01:20, 33.99it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/az/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/bg/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   1%|          | 16/2750 [00:00<01:19, 34.37it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/bn/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/bs/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   1%|          | 20/2750 [00:00<01:16, 35.56it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ca/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ckb/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   1%|          | 24/2750 [00:00<01:14, 36.71it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/cs/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/cy/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   1%|          | 28/2750 [00:00<01:13, 37.08it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/da/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/de/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   1%|          | 32/2750 [00:00<01:12, 37.51it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/de_CH/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/el/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   1%|▏         | 36/2750 [00:00<01:12, 37.63it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/en/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/en_AU/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   1%|▏         | 40/2750 [00:01<01:13, 36.71it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/en_GB/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/en_IE/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   2%|▏         | 44/2750 [00:01<01:13, 36.69it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/eo/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/es/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   2%|▏         | 48/2750 [00:01<01:13, 36.87it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/es_AR/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/es_CO/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   2%|▏         | 52/2750 [00:01<01:13, 36.50it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/es_MX/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/es_NI/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   2%|▏         | 56/2750 [00:01<01:13, 36.61it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/es_PR/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/et/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   2%|▏         | 60/2750 [00:01<01:12, 37.02it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/eu/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/fa/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   2%|▏         | 64/2750 [00:01<01:12, 36.81it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/fi/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/fr/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   2%|▏         | 68/2750 [00:01<01:13, 36.56it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/fy/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ga/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   3%|▎         | 72/2750 [00:01<01:13, 36.46it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/gd/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/gl/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   3%|▎         | 76/2750 [00:02<01:13, 36.36it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/he/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/hi/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   3%|▎         | 80/2750 [00:02<01:13, 36.33it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/hr/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/hu/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   3%|▎         | 84/2750 [00:02<01:13, 36.38it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/id/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ig/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   3%|▎         | 88/2750 [00:02<01:13, 36.32it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/is/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/it/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   3%|▎         | 92/2750 [00:02<01:13, 36.33it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ja/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ka/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   3%|▎         | 96/2750 [00:02<01:12, 36.40it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/km/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/kn/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   4%|▎         | 100/2750 [00:02<01:12, 36.34it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ko/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ky/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   4%|▍         | 104/2750 [00:02<01:12, 36.27it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/lt/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/lv/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   4%|▍         | 108/2750 [00:02<01:12, 36.28it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/mk/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ml/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   4%|▍         | 112/2750 [00:03<01:12, 36.29it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/mn/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ms/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   4%|▍         | 116/2750 [00:03<01:12, 36.42it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/nb/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/nl/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   4%|▍         | 120/2750 [00:03<01:11, 36.54it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/nn/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/pl/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   5%|▍         | 124/2750 [00:03<01:11, 36.70it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/pt/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/pt_BR/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   5%|▍         | 128/2750 [00:03<01:11, 36.86it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ro/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ru/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   5%|▍         | 132/2750 [00:03<01:11, 36.86it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/sk/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/sl/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   5%|▍         | 136/2750 [00:03<01:11, 36.66it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/sq/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/sr/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   5%|▌         | 140/2750 [00:03<01:11, 36.60it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/sr_Latn/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/sv/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   5%|▌         | 144/2750 [00:03<01:11, 36.36it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/ta/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/te/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   5%|▌         | 148/2750 [00:04<01:11, 36.25it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/tg/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/th/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   6%|▌         | 152/2750 [00:04<01:11, 36.23it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/tk/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/tr/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   6%|▌         | 156/2750 [00:04<01:12, 35.66it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/uk/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/uz/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   6%|▌         | 160/2750 [00:04<01:12, 35.90it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/vi/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/zh_Hans/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   6%|▌         | 164/2750 [00:04<01:11, 36.05it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/locale/zh_Hant/formats.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/urls/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/urls/i18n.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   6%|▌         | 168/2750 [00:04<01:11, 35.95it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/conf/urls/static.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/actions.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   6%|▋         | 172/2750 [00:04<01:11, 35.98it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/apps.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/checks.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/decorators.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/exceptions.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   6%|▋         | 176/2750 [00:04<01:12, 35.53it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/filters.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/forms.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/helpers.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/migrations/0001_initial.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   7%|▋         | 180/2750 [00:04<01:12, 35.46it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/migrations/0002_logentry_remove_auto_add.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/migrations/0003_logentry_add_action_flag_choices.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   7%|▋         | 184/2750 [00:05<01:11, 35.88it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/options.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/sites.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/templatetags/admin_list.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   7%|▋         | 188/2750 [00:05<01:12, 35.16it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/templatetags/admin_modify.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/templatetags/admin_urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/templatetags/base.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/templatetags/log.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   7%|▋         | 192/2750 [00:05<01:12, 35.26it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/tests.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/utils.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/views/autocomplete.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   7%|▋         | 196/2750 [00:05<01:12, 35.36it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/views/decorators.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/views/main.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admin/widgets.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   7%|▋         | 200/2750 [00:05<01:12, 35.22it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admindocs/apps.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admindocs/middleware.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admindocs/urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admindocs/utils.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   7%|▋         | 204/2750 [00:05<01:11, 35.51it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/admindocs/views.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/admin.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/apps.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   8%|▊         | 208/2750 [00:05<01:10, 35.83it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/backends.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/base_user.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/checks.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/context_processors.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   8%|▊         | 212/2750 [00:05<01:10, 35.77it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/decorators.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/forms.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/handlers/modwsgi.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   8%|▊         | 216/2750 [00:05<01:09, 36.46it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/hashers.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/management/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/management/commands/changepassword.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   8%|▊         | 220/2750 [00:06<01:08, 37.00it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/management/commands/createsuperuser.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/middleware.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0001_initial.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0002_alter_permission_name_max_length.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   8%|▊         | 224/2750 [00:06<01:08, 36.80it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0003_alter_user_email_max_length.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0004_alter_user_username_opts.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0005_alter_user_last_login_null.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0006_require_contenttypes_0002.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   8%|▊         | 228/2750 [00:06<01:08, 36.67it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0007_alter_validators_add_error_messages.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0008_alter_user_username_max_length.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0009_alter_user_last_name_max_length.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0010_alter_group_name_max_length.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   8%|▊         | 232/2750 [00:06<01:07, 37.07it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0011_update_proxy_permissions.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/migrations/0012_alter_user_first_name_max_length.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/mixins.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   9%|▊         | 236/2750 [00:06<01:07, 37.44it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/password_validation.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/signals.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/tokens.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   9%|▊         | 240/2750 [00:06<01:07, 37.20it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/validators.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/auth/views.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   9%|▉         | 244/2750 [00:06<01:06, 37.54it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/admin.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/apps.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/checks.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/fields.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   9%|▉         | 248/2750 [00:06<01:07, 37.10it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/forms.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/management/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/management/commands/remove_stale_contenttypes.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   9%|▉         | 252/2750 [00:06<01:06, 37.42it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/migrations/0001_initial.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/migrations/0002_remove_content_type_name.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   9%|▉         | 256/2750 [00:07<01:06, 37.39it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/contenttypes/views.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/admin.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/apps.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:   9%|▉         | 260/2750 [00:07<01:07, 36.83it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/forms.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/middleware.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/migrations/0001_initial.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  10%|▉         | 264/2750 [00:07<01:07, 36.71it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/sitemaps.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/templatetags/flatpages.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  10%|▉         | 268/2750 [00:07<01:06, 37.09it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/flatpages/views.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/admin/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  10%|▉         | 272/2750 [00:07<01:07, 36.91it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/admin/options.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/apps.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  10%|█         | 276/2750 [00:07<01:06, 37.44it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/base/adapter.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/base/features.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/base/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  10%|█         | 280/2750 [00:07<01:05, 37.57it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/base/operations.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/mysql/base.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/mysql/features.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  10%|█         | 284/2750 [00:07<01:05, 37.75it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/mysql/introspection.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/mysql/operations.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/mysql/schema.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  10%|█         | 288/2750 [00:07<01:04, 37.91it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/oracle/adapter.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/oracle/base.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/oracle/features.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/oracle/introspection.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  11%|█         | 292/2750 [00:07<01:04, 38.11it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/oracle/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/oracle/operations.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/oracle/schema.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  11%|█         | 296/2750 [00:08<01:04, 38.20it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/adapter.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/base.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/const.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/features.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  11%|█         | 300/2750 [00:08<01:03, 38.31it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/introspection.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/operations.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/pgraster.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  11%|█         | 304/2750 [00:08<01:03, 38.24it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/postgis/schema.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/spatialite/adapter.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/spatialite/base.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  11%|█         | 308/2750 [00:08<01:03, 38.45it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/spatialite/client.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/spatialite/features.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/spatialite/introspection.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split django/contrib/gis/db/backends/spatialite/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# ...
# Parsing nodes:  97%|█████████▋| 2663/2750 [01:11<00:02, 38.58it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_archive.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_autoreload.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_connection.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  97%|█████████▋| 2667/2750 [01:11<00:02, 38.37it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_crypto.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_datastructures.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_dateformat.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_dateparse.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  97%|█████████▋| 2671/2750 [01:11<00:02, 37.91it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_deconstruct.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_decorators.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_duration.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_encoding.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  97%|█████████▋| 2675/2750 [01:11<00:01, 38.35it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_feedgenerator.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_functional.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_hashable.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_html.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  97%|█████████▋| 2679/2750 [01:11<00:01, 38.38it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_http.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_inspect.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_ipv6.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_jslex.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  98%|█████████▊| 2683/2750 [01:11<00:01, 38.37it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_lazyobject.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_lorem_ipsum.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_module/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  98%|█████████▊| 2687/2750 [01:11<00:01, 37.88it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_module/another_bad_module.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_module/another_good_module.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_module/bad_module.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  98%|█████████▊| 2691/2750 [01:12<00:01, 38.03it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_module/child_module/grandchild_module.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_module/good_module.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_module_loading.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  98%|█████████▊| 2695/2750 [01:12<00:01, 38.50it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_no_submodule.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_numberformat.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_os_utils.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_regex_helper.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  98%|█████████▊| 2699/2750 [01:12<00:01, 38.66it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_safestring.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_simplelazyobject.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_termcolors.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_text.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  98%|█████████▊| 2703/2750 [01:12<00:01, 38.37it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_timesince.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_timezone.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/test_tree.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/utils_tests/utils.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  98%|█████████▊| 2707/2750 [01:12<00:01, 38.32it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/__init__.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/test_constraints.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/test_custom_messages.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  99%|█████████▊| 2711/2750 [01:12<00:01, 38.54it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/test_error_messages.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/test_picklable.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/test_unique.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/test_validators.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  99%|█████████▊| 2715/2750 [01:12<00:00, 38.49it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validation/tests.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/validators/tests.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  99%|█████████▉| 2719/2750 [01:12<00:00, 37.90it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/version/tests.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  99%|█████████▉| 2723/2750 [01:12<00:00, 38.17it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/default_urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  99%|█████████▉| 2728/2750 [01:13<00:00, 39.09it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/generic_urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/regression_21530_urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  99%|█████████▉| 2732/2750 [01:13<00:00, 39.17it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/templatetags/debugtags.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/tests/test_csrf.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/tests/test_debug.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes:  99%|█████████▉| 2736/2750 [01:13<00:00, 38.64it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/tests/test_defaults.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/tests/test_i18n.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/tests/test_json.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/tests/test_specials.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes: 100%|█████████▉| 2740/2750 [01:13<00:00, 38.71it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/tests/test_static.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/view_tests/views.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes: 100%|█████████▉| 2744/2750 [01:13<00:00, 38.44it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/wsgi/tests.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/wsgi/urls.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/wsgi/wsgi.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes: 100%|█████████▉| 2748/2750 [01:13<00:00, 38.26it/s]WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/xor_lookups/models.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# WARNING:llama_index.core.node_parser.node_utils:Failed to use epic splitter to split tests/xor_lookups/tests.py. Fallback to treesitter_split(). Error: too many values to unpack (expected 2)
# Parsing nodes: 100%|██████████| 2750/2750 [01:13<00:00, 37.36it/s]
# INFO:moatless.index.code_index:Prepared 0 nodes and 0 tokens
# Generating embeddings: 0it [00:00, ?it/s]
# INFO:moatless.index.code_index:Embedded 0 vectors with 0 tokens
# Indexed 0 nodes and 0 tokens

# %%
code_index.search(query=".")
# Out:
# INFO:moatless.index.code_index:vector_search() Searching for query [....] and file pattern [None].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# SearchCodeResponse(message='Found 0 code spans.', hits=[])

# %% [markdown]
# Then use the `SearchLoop` to find the relevant code.

# %%
from moatless.transitions import search_transitions
from moatless import AgenticLoop


instructions = """
Squashing migrations with Meta.index_together -> indexes transition should remove deprecation warnings.
Description

Squashing migrations with Meta.index_together -> Meta.indexes transition should remove deprecation warnings. As far as I'm aware, it's a 4.2 release blocker because you cannot get rid of the index_together deprecation warnings without rewriting migrations, see comment.
"""

transitions = search_transitions(model=model)
search_loop = AgenticLoop(transitions, workspace=workspace)

search_response = search_loop.run(instructions)
print(search_response.message)

print(workspace.file_context.create_prompt())
# Out:
# INFO:moatless.transitions:{<class 'moatless.find.decide.DecideRelevance'>: {'max_iterations': 5}}
# INFO:Loop:Transitioning from Pending to SearchCode
# INFO:moatless.index.code_index:vector_search() Searching for query [
# Squashing migrations with Meta.index_together -> ...] and file pattern [None].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.trajectory:Getting transitions for SearchCode from 0 transitions.
# INFO:Loop:SearchCode Create completion with 2 messages
# 14:53:40 - LiteLLM:INFO: utils.py:2794 -
# LiteLLM completion() model= gpt-4o-2024-05-13; provider = openai
# INFO:LiteLLM:
# LiteLLM completion() model= gpt-4o-2024-05-13; provider = openai
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 14:53:41 - LiteLLM:INFO: utils.py:950 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# INFO:Loop:SearchCode: Received new action Search.
# INFO:moatless.index.code_index:vector_search() Searching for query [Meta.index_together file:**/migrations/**/*.py...] and file pattern [**/migrations/**/*.py].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.index.code_index:vector_search() Searching for query [Meta.indexes file:**/migrations/**/*.py...] and file pattern [**/migrations/**/*.py].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.index.code_index:vector_search() Searching for query [Meta.index_together file:**/models/**/*.py...] and file pattern [**/models/**/*.py].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.index.code_index:vector_search() Searching for query [Meta.indexes file:**/models/**/*.py...] and file pattern [**/models/**/*.py].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.find.search_v2:Found 0 hits.
# INFO:moatless.find.search_v2:No search results found. Will retry.
# INFO:moatless.trajectory:Saving action Search to SearchCode (1 actions)
# INFO:Loop:SearchCode: Retry requested.
#
# Unfortunately, I didn’t find any relevant results.
# INFO:moatless.index.code_index:vector_search() Searching for query [
# Squashing migrations with Meta.index_together -> ...] and file pattern [None].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.trajectory:Getting transitions for SearchCode from 0 transitions.
# INFO:Loop:SearchCode Create completion with 4 messages
# 14:53:50 - LiteLLM:INFO: utils.py:2794 -
# LiteLLM completion() model= gpt-4o-2024-05-13; provider = openai
# INFO:LiteLLM:
# LiteLLM completion() model= gpt-4o-2024-05-13; provider = openai
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 14:53:51 - LiteLLM:INFO: utils.py:950 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# INFO:Loop:SearchCode: Received new action Search.
# INFO:moatless.index.code_index:vector_search() Searching for query [Meta.index_together file:**/*.py...] and file pattern [**/*.py].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.index.code_index:vector_search() Searching for query [Meta.indexes file:**/*.py...] and file pattern [**/*.py].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.find.search_v2:Found 0 hits.
# INFO:moatless.find.search_v2:No search results found. Will retry.
# INFO:moatless.trajectory:Saving action Search to SearchCode (2 actions)
# INFO:Loop:SearchCode: Retry requested.
#
# Unfortunately, I didn’t find any relevant results.
# INFO:moatless.index.code_index:vector_search() Searching for query [
# Squashing migrations with Meta.index_together -> ...] and file pattern [None].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.trajectory:Getting transitions for SearchCode from 0 transitions.
# INFO:Loop:SearchCode Create completion with 6 messages
# 14:53:57 - LiteLLM:INFO: utils.py:2794 -
# LiteLLM completion() model= gpt-4o-2024-05-13; provider = openai
# INFO:LiteLLM:
# LiteLLM completion() model= gpt-4o-2024-05-13; provider = openai
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 14:53:59 - LiteLLM:INFO: utils.py:950 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# INFO:Loop:SearchCode: Received new action Search.
# INFO:moatless.index.code_index:vector_search() Searching for query [Django migration file:**/migrations/**/*.py...] and file pattern [**/migrations/**/*.py].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:moatless.index.code_index:vector_search() Returning 0 search results. (Ignored 0 removed search results. Filtered out 0 search results.)
# INFO:moatless.index.code_index:semantic_search() Found 0 code spans in 0 files.
# INFO:moatless.find.search_v2:Found 0 hits.
# INFO:moatless.find.search_v2:No search results found. Will retry.
# INFO:moatless.trajectory:Saving action Search to SearchCode (3 actions)
# INFO:Loop:SearchCode: Retry requested.
#
# Unfortunately, I didn’t find any relevant results.
# WARNING:Loop:Max retries reached (2). Exiting.
# The loop was aborted because the number of retries exceeded the limit.

# %% [markdown]
# Execute the `CodeLoop` to apply the changes.

# %%
from moatless.transitions import code_transitions

code_loop = AgenticLoop(transitions=code_transitions(), workspace=workspace)
code_response = code_loop.run(instructions)

print(f"Response: {code_response.message}")
# Out:
# Response: The token limit check has been successfully removed from the `completion` function in moatless/llm/completion.py.

# %% [markdown]
# Run a `$ git diff` to see the changes.

# %%
import subprocess

output = subprocess.run(
      ["git", "diff"],
      capture_output=True,
      text=True,
      cwd=repo_dir,
)

print(output.stdout)
# Out:
# diff --git a/moatless/llm/completion.py b/moatless/llm/completion.py
# index 2c95e47..a926948 100644
# --- a/moatless/llm/completion.py
# +++ b/moatless/llm/completion.py
# @@ -48,10 +48,6 @@ def completion(
#
#      metadata["trace_name"] = trace_name
#
# -    tokens = token_counter(messages=messages[-1:])
# -    if tokens > Settings.max_message_tokens:
# -        raise ValueError(f"Too many tokens in the new message: {tokens}")
# -
#      response = litellm.completion(
#          model=model,
#          max_tokens=max_tokens,
